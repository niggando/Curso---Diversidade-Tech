# %% [markdown]
# ## Técnicas de Programação I - Introdução Pandas
#
# Na aula de hoje iremos explorar os seguintes tópicos:
#
# - Pandas

# %% [markdown]
# ### 1) Pandas
#
# O **[Pandas](https://pandas.pydata.org/)** é uma das bibliotecas mais usadas em data science.
#
# Esta biblioteca, construída a partir do Numpy, possibilita a estruturação e manipulação de dados de maneira simples e eficiente.
#
# Comos os dados são a matéria prima de todo projeto de data science, manipulá-los é fundamental! Por isso, utilizaremos o Pandas em quase todas as aulas daqui pra frente!

# %% [markdown]
# ### DataFrame
#
# O objeto do Pandas que mais utilizaremos será o **DataFrame**
#
# Como veremos a seguir, o DataFrame é uma estrutura que se assemalha a uma **tabela**.

# %% [markdown]
# ### Lendo dados de um arquivo
#
# A forma mais comum de se construir um dataframe é a partir da **leitura de um arquivo**
#
# Em geral, queremos ler arquivos já estruturados como base de dados, em formatos como .csv, .txt, .xlsx, etc.
#
# O pandas é capaz de ler todos esses formatos, com funções específicas!

# %% [markdown]
# ### 1. Faça um programa que imprima as linhas do arquivo alunos.csv

# %%
import pandas as pd

# %%
# Carregando o arquivo alunos.csv
# O separador das colunas não é ';' e sim ','
df = pd.read_csv("./datasets/alunos.csv", sep = ';')

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
# Somente no Jupyter
# Permite visualizar
display(df)
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
# Pegando o nome das colunas
# Para cada coluna dentro do DataFrame, imprima a coluna
for col in df:
    print(col)
# Out:
# RA
# Nome
# Frequencia
# Prova_1
# Prova_2
# Prova_3
# Prova_4

# %%
# Esse comportamento é semelhante ao dicionário!

dc = {
    'key1': 1,
    'key2': 2,
    'key3': 3
}

for key in dc:
    print(key)
# Out:
# key1
# key2
# key3

# %%
# Armazenando o nome das colunas em uma lista

cols = []
for col in df:
    print(col)
    cols.append(col)
# Out:
# RA
# Nome
# Frequencia
# Prova_1
# Prova_2
# Prova_3
# Prova_4

# %%
cols
# Out:
# ['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']

# %%
# Pegando as colunas do DataFrame
print(df.columns)
print(type(df.columns))
print('-'*32)
print('lista col:', list(df.columns))
print('-'*32)
print('lista col:', df.columns.tolist()) # Transformando o Index (que é um np.array) em lista
print('-'*32)
print('lista col:', df.keys().tolist())
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# --------------------------------
# lista col: ['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']
# --------------------------------
# lista col: ['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']
# --------------------------------
# lista col: ['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']

# %%
# Acessando os primeiros 'n' elementos
df.head(3)
# Out:
#        RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201  Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212     Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218   Carlos Vernes          17      7.0      7.0      7.0        7

# %%
df.head(5)
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7

# %%
# Acessando os 'n' últimos elementos
df.tail(3)
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %% [markdown]
# **Drops**
#
# Imagine que você trabalhe num restaurante. Durante o dia, diversas gorjetas são pagas pelas pessoas clientes. No restaurante, você decide compreender o comportamento das pessoas clientes, que são as boas pagadoras de gorjeta e quem paga menos, quais os melhores dias e turnos que essas ocorrem.
#
# Primeiramente precisamos realizar o carregamento do arquivo e observar quais valores temos, portanto:
# - Leia o arquivo `tips`.
# - Mostre as 10 primeiras linhas do dataframe
# - Mostre as 7 últimas linhas do dataframe

# %%
df2 = pd.read_csv("./datasets/tips.csv", sep = ',')

# %%
df2
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
# Gorjetas mais fracas = primeiros itens
display(df2.head(10))
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4
# 5           5       25.29  4.71    Male     No  Sun  Dinner     4
# 6           6        8.77  2.00    Male     No  Sun  Dinner     2
# 7           7       26.88  3.12    Male     No  Sun  Dinner     4
# 8           8       15.04  1.96    Male     No  Sun  Dinner     2
# 9           9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# Melhores gorjetas = últimas linhas

display(df2.tail(7))
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 237         237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238         238       35.83  4.67  Female     No   Sat  Dinner     3
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# A Variável df é do tipo DataFrame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Selecionando uma coluna
df['Frequencia']
# Out:
# 0    20
# 1    20
# 2    17
# 3    20
# 4    15
# 5    18
# 6    20
# 7    20
# 8    19
# 9    20
# Name: Frequencia, dtype: int64

# %%
# Podemos pegar várias colunas ao mesmo tempo
df2 = df[['Frequencia', 'Prova_1', 'RA']]
df2
# Out:
#    Frequencia  Prova_1      RA
# 0          20      6.5  110201
# 1          20      7.0  110212
# 2          17      7.0  110218
# 3          20      9.0  110307
# 4          15      6.5  110275
# 5          18      7.5  110281
# 6          20      5.0  110301
# 7          20     10.0  110263
# 8          19      9.5  110271
# 9          20      8.0  110236

# %%
# Podemos pegar várias colunas ao mesmo tempo
# Atribuindo uma variável aos titulos das colunas selecionadas.
colunas_selecionadas =df[['Frequencia', 'Prova_1', 'RA']]
df3 = colunas_selecionadas
df3
# Out:
#    Frequencia  Prova_1      RA
# 0          20      6.5  110201
# 1          20      7.0  110212
# 2          17      7.0  110218
# 3          20      9.0  110307
# 4          15      6.5  110275
# 5          18      7.5  110281
# 6          20      5.0  110301
# 7          20     10.0  110263
# 8          19      9.5  110271
# 9          20      8.0  110236

# %%
# Assim como no numpy, podemos acessar as dimensões da tabela
# utilizando shape
df.shape
# Out:
# (10, 7)

# %%
n_linhas, n_cols = df.shape
print(f'''
O dataframe tem:
{n_linhas} linhas
{n_cols} colunas''')
# Out:
# O dataframe tem:
# 10 linhas
# 7 colunas

# %%
# Uma série é na verdade um array unidimensional (vetor):
df['RA'].shape
# Out:
# (10,)

# %%
# Pegando uma linha específica
# Primeira linha
df.loc[0]
# Out:
# RA                    110201
# Nome          Antonio Carlos
# Frequencia                20
# Prova_1                  6.5
# Prova_2                  8.5
# Prova_3                  7.0
# Prova_4                    6
# Name: 0, dtype: object

# %%
# Uma série (vetor), porém temos os nomes dos índices
df.loc[0].shape
# Out:
# (7,)

# %%
# Parece um dicionário
# Conseguimos pegar os valores  da linha de values
df.loc[0].values
# Out:
# array([110201, 'Antonio Carlos', 20, 6.5, 8.5, 7.0, 6], dtype=object)

# %%
# Pegando a primeira linha e uma coluna específica
df.loc[0:3, 'Nome']
# Out:
# 0     Antonio Carlos
# 1        Ana Beatriz
# 2      Carlos Vernes
# 3    Francisco Cunha
# Name: Nome, dtype: object

# %% [markdown]
# ## Faça um programa que imprima as linhas do arquivo alunos.csv como listas

# %%
# utilizando o range
for i in range(df.shape[0]):
    print(df.loc[i].values.tolist())
# Out:
# [110201, 'Antonio Carlos', 20, 6.5, 8.5, 7.0, 6]
# [110212, 'Ana Beatriz', 20, 7.0, 7.0, 7.0, 8]
# [110218, 'Carlos Vernes', 17, 7.0, 7.0, 7.0, 7]
# [110307, 'Francisco Cunha', 20, 9.0, 8.5, 8.5, 10]
# [110275, 'Sandra Rosa', 15, 6.5, 7.5, 7.0, 7]
# [110281, 'Juliana Arruda', 18, 7.5, 7.0, 7.5, 8]
# [110301, 'Joao Galo', 20, 5.0, 6.5, 7.0, 5]
# [110263, 'José Valente', 20, 10.0, 10.0, 10.0, 10]
# [110271, 'Maria Ferreira', 19, 9.5, 8.0, 7.0, 10]
# [110236, 'Adriana Tavares', 20, 8.0, 8.0, 8.0, 8]

# %%
# Utilizando o 'iterrows'
# Permite iterar linha a linha

for i, linha in df.iterrows():
    print(i, linha.values.tolist())
# Out:
# 0 [110201, 'Antonio Carlos', 20, 6.5, 8.5, 7.0, 6]
# 1 [110212, 'Ana Beatriz', 20, 7.0, 7.0, 7.0, 8]
# 2 [110218, 'Carlos Vernes', 17, 7.0, 7.0, 7.0, 7]
# 3 [110307, 'Francisco Cunha', 20, 9.0, 8.5, 8.5, 10]
# 4 [110275, 'Sandra Rosa', 15, 6.5, 7.5, 7.0, 7]
# 5 [110281, 'Juliana Arruda', 18, 7.5, 7.0, 7.5, 8]
# 6 [110301, 'Joao Galo', 20, 5.0, 6.5, 7.0, 5]
# 7 [110263, 'José Valente', 20, 10.0, 10.0, 10.0, 10]
# 8 [110271, 'Maria Ferreira', 19, 9.5, 8.0, 7.0, 10]
# 9 [110236, 'Adriana Tavares', 20, 8.0, 8.0, 8.0, 8]

# %%
df.loc[0][['Prova_3', 'Prova_4']].values
# Out:
# array([7.0, 6], dtype=object)

# %%
# Utilizando o 'iterrows'
# Permite iterar linha a linha

for i, linha in df.iterrows():
    # Utilizando compreensões de lista para converter o valor
    # da célula em string!
    lista_valores = [str(valor) for valor in linha.values]
    # Utilizando a conversão de tipos do numpy
    lista_valores = linha.values.astype('str') # Coloca 'str' para converter em string cada campo
    print(i, lista_valores)
# Out:
# 0 ['110201' 'Antonio Carlos' '20' '6.5' '8.5' '7.0' '6']
# 1 ['110212' 'Ana Beatriz' '20' '7.0' '7.0' '7.0' '8']
# 2 ['110218' 'Carlos Vernes' '17' '7.0' '7.0' '7.0' '7']
# 3 ['110307' 'Francisco Cunha' '20' '9.0' '8.5' '8.5' '10']
# 4 ['110275' 'Sandra Rosa' '15' '6.5' '7.5' '7.0' '7']
# 5 ['110281' 'Juliana Arruda' '18' '7.5' '7.0' '7.5' '8']
# 6 ['110301' 'Joao Galo' '20' '5.0' '6.5' '7.0' '5']
# 7 ['110263' 'José Valente' '20' '10.0' '10.0' '10.0' '10']
# 8 ['110271' 'Maria Ferreira' '19' '9.5' '8.0' '7.0' '10']
# 9 ['110236' 'Adriana Tavares' '20' '8.0' '8.0' '8.0' '8']

# %% [markdown]
# ##  Faça um programa que imprima os elementos da coluna ‘Nome’ do arquivo alunos.csv.

# %%
# Primeira opção
display(df['Nome'])
print('-'*32)
display(df['Nome'][3:5])
# Out:
# 0     Antonio Carlos
# 1        Ana Beatriz
# 2      Carlos Vernes
# 3    Francisco Cunha
# 4        Sandra Rosa
# 5     Juliana Arruda
# 6          Joao Galo
# 7       José Valente
# 8     Maria Ferreira
# 9    Adriana Tavares
# Name: Nome, dtype: object
# --------------------------------
# 3    Francisco Cunha
# 4        Sandra Rosa
# Name: Nome, dtype: object

# %%
# Melhor forma, utilizando o 'loc' 
df.loc[3:4, 'Nome'] # O Loc é inclusivo
# Out:
# 3    Francisco Cunha
# 4        Sandra Rosa
# Name: Nome, dtype: object

# %%
# Iterando sobre os valores da coluna nome
for nome in df['Nome'].values:
    print(nome)
# Out:
# Antonio Carlos
# Ana Beatriz
# Carlos Vernes
# Francisco Cunha
# Sandra Rosa
# Juliana Arruda
# Joao Galo
# José Valente
# Maria Ferreira
# Adriana Tavares

# %% [markdown]
# ## Faça um programa que copie os dados do arquivo alunos.csv para um arquivo chamado alunos2.csv

# %%
df.to_csv('./datasets/alunos2.csv', sep = ';') # separador é opcional, pois por padrão vem separado por vírgula

# %%
df.to_excel('./datasets/alunos_to_excel.xlsx')

# %%
# Como não mandar o index
df.to_csv('./datasets/alunos2_semIndex.csv', index = None) # separador é opcional, pois por padrão vem separado por vírgula

# %% [markdown]
# ## Faça um programa que imprima o nome e a média de cada um dos alunos do arquivo alunos.csv

# %%
## Moda 
import numpy as np
x = [-1, 2, 1, 3, 3, 4, 5, 5, 5, 3, 5, 2]
vals,counts = np.unique(x, return_counts=True)
vals[counts.argmax()]
# Out:
# 5

# %%
df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']].mean(axis=1)
# Out:
# 0     7.000
# 1     7.250
# 2     7.000
# 3     9.000
# 4     7.000
# 5     7.500
# 6     5.875
# 7    10.000
# 8     8.625
# 9     8.000
# dtype: float64

# %%
# Inserindo colunas
df['Media'] = df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']].mean(axis=1)
df.head(3)
# Out:
#        RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201  Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212     Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218   Carlos Vernes          17      7.0      7.0      7.0        7
#
#    Media
# 0   7.00
# 1   7.25
# 2   7.00

# %%
df2 = df[['Nome', 'Media']]
df2
# Out:
#               Nome   Media
# 0   Antonio Carlos   7.000
# 1      Ana Beatriz   7.250
# 2    Carlos Vernes   7.000
# 3  Francisco Cunha   9.000
# 4      Sandra Rosa   7.000
# 5   Juliana Arruda   7.500
# 6        Joao Galo   5.875
# 7     José Valente  10.000
# 8   Maria Ferreira   8.625
# 9  Adriana Tavares   8.000

# %%
# Ordenando os Valores
df2.sort_values(['Media', 'Nome'], ascending = False)
# Out:
#               Nome   Media
# 7     José Valente  10.000
# 3  Francisco Cunha   9.000
# 8   Maria Ferreira   8.625
# 9  Adriana Tavares   8.000
# 5   Juliana Arruda   7.500
# 1      Ana Beatriz   7.250
# 4      Sandra Rosa   7.000
# 2    Carlos Vernes   7.000
# 0   Antonio Carlos   7.000
# 6        Joao Galo   5.875

# %%
df2 = df2.sort_values('Media', ascending = False)

# %%
df2.to_csv('./datasets/media.csv', index = None)

# %%
for i, row in df2.iterrows():
    print(i, row)
    print(f'idx {i}, nome: {Nome.values}, media: {Media.values}')
    break
# Out:
# 7 Nome     José Valente
# Media            10.0
# Name: 7, dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Viatec\Documents\Estudos\Diversidade Tech\3. DiversidadeTech\Modulo 3 - Técnicas de Programação\3. Pandas\4. Introdução Pandas - Final.ipynb Célula: 55 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/4.%20Introdu%C3%A7%C3%A3o%20Pandas%20-%20Final.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> for i, row in df2.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/4.%20Introdu%C3%A7%C3%A3o%20Pandas%20-%20Final.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a>     print(i, row)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/4.%20Introdu%C3%A7%C3%A3o%20Pandas%20-%20Final.ipynb#Y105sZmlsZQ%3D%3D?line=2'>3</a>     print(f'idx {i}, nome: {Nome}, media: {Media}')
#       <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/4.%20Introdu%C3%A7%C3%A3o%20Pandas%20-%20Final.ipynb#Y105sZmlsZQ%3D%3D?line=3'>4</a>     break
#
# NameError: name 'Nome' is not defined

# %% [markdown]
# ## Faça um programa que crie um arquivo media.csv e guarde o RA
# (registro do aluno) junto com a respectiva média de cada um dos
# alunos no arquivo alunos.csv.

# %% [markdown]
# **Drops**
#
# Utilizando o dado `tips.csv`.
#
# Gere a média, mediana e o desvio padrão das colunas:
# - `total_bill`
# - `tip`
# - `size`

# %%
df_tips = pd.read_csv('./datasets/tips.csv')
df_tips
# df['Media'] = df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']].mean(axis=1)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
# Quanto utilizamos 'Axis=1' no pandas, ele retorna os valores consolidados por coluna
# Quando utilizamos 'Axis = 1" no numpy, ele retorna os valores consolidados por linha
media = df_tips[['total_bill', 'tip', 'size']].mean()
desvio = df_tips[['total_bill', 'tip', 'size']].std()

# No pandas, o median já retorna a mediana
mediana = df_tips[['total_bill', 'tip', 'size']].median()

## Outras soluções
# mediana = np.quantile(df_tips[['total_bill', 'tip', 'size']], 0.5, axis = 0)
# mediana = df_tips[['total_bill','tip','size']].quantile(0.5)

print('media')
print(media)
print('-'*32)

print('desvio padrão')
print(desvio)
print('-'*32)

print('mediana')
print(mediana)
print('-'*32)
# Out:
# media
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64
# --------------------------------
# desvio padrão
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64
# --------------------------------
# mediana
# total_bill    17.795
# tip            2.900
# size           2.000
# dtype: float64
# --------------------------------
