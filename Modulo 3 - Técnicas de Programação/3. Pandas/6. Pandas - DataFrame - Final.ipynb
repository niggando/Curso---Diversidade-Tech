# %% [markdown]
# ## Técnicas de Programação I - Pandas
#
# Na aula de hoje iremos explorar os seguintes tópicos:
#
# - Pandas - DataFrame

# %% [markdown]
# ### DataFrame
#
# Agora que conhecemos as séries, vamos partir pro objeto do Pandas que mais utilizaremos: o **DataFrame**
#
# Como veremos a seguir, o DataFrame é uma estrutura que se assemalha a uma **tabela**.
#
# Estruturalmente, o DataFrame nada mais é que um **conjunto de Series**, uma para cada coluna (e, claro, com mesmo índice, que irão indexar as linhas).
#
# Veremos depois como **ler um dataframe a partir de um arquivo** (que é provavelmente a forma mais comum)
#
# Há muitas formas de construir um DataFrame do zero. Todas elas fazem uso da função **pd.DataFrame()**, como veremos a seguir.
#
# Se quisermos especificar os índices de linha, o nome das colunas, e os dados, podemos passá-los separadamente:

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)
m = np.random.randint(-100, 100, (5, 3))
pd.DataFrame(m)
# Out:
#     0   1   2
# 0   2  79  -8
# 1 -86   6 -29
# 2  88 -80   2
# 3  21 -26 -13
# 4  16  -1   3

# %%
# Criando um DataFrame nomeando as colunas e indices
df_nome_linhas = pd.DataFrame(
    data = m, # Dados formato tabular
    index = ['obs1', 'obs2', 'obs3', 'obs4', 'obs5'], # Nomeando as linhas, opcional
    columns = ['variavel_1', 'variavel_2', 'variavel_3'] # Nomeando as colunas, opcional
)
df_nome_linhas
# Out:
#       variavel_1  variavel_2  variavel_3
# obs1           2          79          -8
# obs2         -86           6         -29
# obs3          88         -80           2
# obs4          21         -26         -13
# obs5          16          -1           3

# %%
# Pegando apenas uma linha
df_nome_linhas.loc['obs3']
# ou
# df_nome_linhas.iloc[2]
# Out:
# variavel_1    88
# variavel_2   -80
# variavel_3     2
# Name: obs3, dtype: int32

# %%
# Um valor específico
df_nome_linhas.loc['obs3', 'variavel_2']
# Out:
# -80

# %%
# Selecionando todas as linhas de uma dada coluna
# Retorna uma série
df_nome_linhas['variavel_2']
# Out:
# obs1    79
# obs2     6
# obs3   -80
# obs4   -26
# obs5    -1
# Name: variavel_2, dtype: int32

# %%
# Selecionando todas as linhas de uma dada coluna utilizando o .loc
df_nome_linhas.loc[:, 'variavel_2']
# Out:
# obs1    79
# obs2     6
# obs3   -80
# obs4   -26
# obs5    -1
# Name: variavel_2, dtype: int32

# %%
# Utilizando o iloc
df_nome_linhas.iloc[2, 1]
# Out:
# -80

# %%
# Podemos utilizar o loc ou iloc com listas
display(df_nome_linhas)

display(df_nome_linhas.loc[['obs1', 'obs3'], ['variavel_1', 'variavel_3']])

display(df_nome_linhas.iloc[[0, 2], [0, 1]])
# Out:
#       variavel_1  variavel_2  variavel_3
# obs1           2          79          -8
# obs2         -86           6         -29
# obs3          88         -80           2
# obs4          21         -26         -13
# obs5          16          -1           3
#       variavel_1  variavel_3
# obs1           2          -8
# obs3          88           2
#       variavel_1  variavel_2
# obs1           2          79
# obs3          88         -80

# %%
# Número de colunas com o shape
print('colunas shape', df_nome_linhas.shape[1])
# Número de colunas com o len
print('colunas len de colunas: ', len(df_nome_linhas.columns))
# Out:
# colunas shape 3
# colunas len de colunas:  3

# %%
# Número de linhas com shape
print('linhas shape', df_nome_linhas.shape[0])
# Com len
print('linhas len', len(df_nome_linhas))
# Ou
print('linhas len(index)',len(df_nome_linhas.index))
# Out:
# linhas shape 5
# linhas len 5
# linhas len(index) 5

# %%
df_nome_colunas = pd.DataFrame(m,
                              columns=['variavel_1', 'variavel_2', 'variavel_3'])

# %%
df_nome_colunas
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3

# %%
# O dataframe parece um dict
df_nome_colunas.to_dict()
# Out:
# {'variavel_1': {0: 2, 1: -86, 2: 88, 3: 21, 4: 16},
#  'variavel_2': {0: 79, 1: 6, 2: -80, 3: -26, 4: -1},
#  'variavel_3': {0: -8, 1: -29, 2: 2, 3: -13, 4: 3}}

# %%
for coluna, valores in df_nome_colunas.to_dict().items():
    print('Coluna', coluna)
    for idx, valor in valores.items():
        print('idx', idx, 'valor:', valor)
    print('-'*32)
# Out:
# Coluna variavel_1
# idx 0 valor: 2
# idx 1 valor: -86
# idx 2 valor: 88
# idx 3 valor: 21
# idx 4 valor: 16
# --------------------------------
# Coluna variavel_2
# idx 0 valor: 79
# idx 1 valor: 6
# idx 2 valor: -80
# idx 3 valor: -26
# idx 4 valor: -1
# --------------------------------
# Coluna variavel_3
# idx 0 valor: -8
# idx 1 valor: -29
# idx 2 valor: 2
# idx 3 valor: -13
# idx 4 valor: 3
# --------------------------------

# %%
df_nome_colunas.to_dict(orient='list')
# Out:
# {'variavel_1': [2, -86, 88, 21, 16],
#  'variavel_2': [79, 6, -80, -26, -1],
#  'variavel_3': [-8, -29, 2, -13, 3]}

# %%
orients = ('dict', 'list', 'series', 'split', 'records', 'index')
for orient in orients:
    print(orient)
    display(df_nome_colunas.to_dict(orient=orient))
    print('-'*32)
# Out:
# dict
# {'variavel_1': {0: 2, 1: -86, 2: 88, 3: 21, 4: 16},
#  'variavel_2': {0: 79, 1: 6, 2: -80, 3: -26, 4: -1},
#  'variavel_3': {0: -8, 1: -29, 2: 2, 3: -13, 4: 3}}
# --------------------------------
# list
# {'variavel_1': [2, -86, 88, 21, 16],
#  'variavel_2': [79, 6, -80, -26, -1],
#  'variavel_3': [-8, -29, 2, -13, 3]}
# --------------------------------
# series
# {'variavel_1': 0     2
#  1   -86
#  2    88
#  3    21
#  4    16
#  Name: variavel_1, dtype: int32,
#  'variavel_2': 0    79
#  1     6
#  2   -80
#  3   -26
#  4    -1
#  Name: variavel_2, dtype: int32,
#  'variavel_3': 0    -8
#  1   -29
#  2     2
#  3   -13
#  4     3
#  Name: variavel_3, dtype: int32}
# --------------------------------
# split
# {'index': [0, 1, 2, 3, 4],
#  'columns': ['variavel_1', 'variavel_2', 'variavel_3'],
#  'data': [[2, 79, -8],
#   [-86, 6, -29],
#   [88, -80, 2],
#   [21, -26, -13],
#   [16, -1, 3]]}
# --------------------------------
# records
# [{'variavel_1': 2, 'variavel_2': 79, 'variavel_3': -8},
#  {'variavel_1': -86, 'variavel_2': 6, 'variavel_3': -29},
#  {'variavel_1': 88, 'variavel_2': -80, 'variavel_3': 2},
#  {'variavel_1': 21, 'variavel_2': -26, 'variavel_3': -13},
#  {'variavel_1': 16, 'variavel_2': -1, 'variavel_3': 3}]
# --------------------------------
# index
# {0: {'variavel_1': 2, 'variavel_2': 79, 'variavel_3': -8},
#  1: {'variavel_1': -86, 'variavel_2': 6, 'variavel_3': -29},
#  2: {'variavel_1': 88, 'variavel_2': -80, 'variavel_3': 2},
#  3: {'variavel_1': 21, 'variavel_2': -26, 'variavel_3': -13},
#  4: {'variavel_1': 16, 'variavel_2': -1, 'variavel_3': 3}}
# --------------------------------

# %%
orients = ('dict', 'list', 'series', 'split', 'records', 'index')
for orient in orients:
    print(orient)
    dicionario_dados = df_nome_colunas.to_dict(orient=orient)
    if orient == 'split':
        display(pd.DataFrame(**dicionario_dados))
    else:
        display(pd.DataFrame(dicionario_dados))
    print('-'*32)
# Out:
# dict
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3
# --------------------------------
# list
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3
# --------------------------------
# series
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3
# --------------------------------
# split
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3
# --------------------------------
# records
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3
# --------------------------------
# index
#              0   1   2   3   4
# variavel_1   2 -86  88  21  16
# variavel_2  79   6 -80 -26  -1
# variavel_3  -8 -29   2 -13   3
# --------------------------------

# %%
df_nome_colunas_transposto = pd.DataFrame(dicionario_dados)
df_nome_colunas_transposto
# Out:
#              0   1   2   3   4
# variavel_1   2 -86  88  21  16
# variavel_2  79   6 -80 -26  -1
# variavel_3  -8 -29   2 -13   3

# %%
# Uma forma rápida de transformar as colunas em linhas e as linhas em colunas
# É realizando a transposta da tabela, utilizando o 'T'
df_nome_colunas_transposto.T
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2          79          -8
# 1         -86           6         -29
# 2          88         -80           2
# 3          21         -26         -13
# 4          16          -1           3

# %%
def elementos(nome, idade, cidade, **kwargs):
    print(nome, idade, cidade)
    print(kwargs)

# %%
config = {
    'nome' : 'Fulano',
    'idade': 32,
    'cidade': 'SP',
    'Hobbies': 'LoL'
}

elementos(**config)
# Out:
# Fulano 32 SP
# {'Hobbies': 'LoL'}

# %%
dict(
    nome = 'fulano',
    idade = 32
)
# Out:
# {'nome': 'fulano', 'idade': 32}

# %% [markdown]
# Outra forma bem natural é utilizar um dicionário cujos valores são listas. Neste caso, as chaves serão o nome das colunas!

# %%
dic = {
    'variavel_1': [2, 79, 78, 88],
    'variavel_2': [-86, 6, 78, 192],
    'variavel_3': [88, -80, 93, 24]
}

df_dic = pd.DataFrame(dic)
df_dic
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2         -86          88
# 1          79           6         -80
# 2          78          78          93
# 3          88         192          24

# %%
# Podemos substituir um valor de uma célula
df_dic.loc[1, 'variavel_1'] = -1000
df_dic
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2         -86          88
# 1       -1000           6         -80
# 2          78          78          93
# 3          88         192          24

# %%
# Utilizando iloc
df_dic.iloc[1, 0] = -150
df_dic
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2         -86          88
# 1        -150           6         -80
# 2          78          78          93
# 3          88         192          24

# %% [markdown]
# Podemos fazer operações com as colunas, dado que elas são séries!

# %%
resultado = df_dic['variavel_1'] + 20
df_dic
# Out:
#    variavel_1  variavel_2  variavel_3
# 0           2         -86          88
# 1        -150           6         -80
# 2          78          78          93
# 3          88         192          24

# %%
resultado
# Out:
# 0     22
# 1   -130
# 2     98
# 3    108
# Name: variavel_1, dtype: int64

# %%
# A partir de uma série

# %%
np.random.seed(42)

notas = pd.Series(np.random.randint(0, 11, 30))
df_notas = pd.DataFrame(notas,columns=['nota'])
# Criando uma coluna nome
df_notas['nome'] = None

df_notas.loc[0: 9, 'nome'] = 'Maria'
df_notas.loc[10: 19,'nome'] = 'João'
df_notas.loc[20: , 'nome'] = 'José'

# %%
df_notas
# Out:
#     nota   nome
# 0      6  Maria
# 1      3  Maria
# 2     10  Maria
# 3      7  Maria
# 4      4  Maria
# 5      6  Maria
# 6      9  Maria
# 7      2  Maria
# 8      6  Maria
# 9     10  Maria
# 10    10   João
# 11     7   João
# 12     4   João
# 13     3   João
# 14     7   João
# 15     7   João
# 16     2   João
# 17     5   João
# 18     4   João
# 19     1   João
# 20     7   José
# 21     5   José
# 22     1   José
# 23     4   José
# 24     0   José
# 25     9   José
# 26     5   José
# 27     8   José
# 28     0   José
# 29    10   José

# %%
# Utilizando o apply
df_notas['e_aprovado'] = df_notas.nota.apply(lambda x: 'Aprovado' if x>5 else 'Reprovado')

# %%
df_notas
# Out:
#     nota   nome e_aprovado
# 0      6  Maria   Aprovado
# 1      3  Maria  Reprovado
# 2     10  Maria   Aprovado
# 3      7  Maria   Aprovado
# 4      4  Maria  Reprovado
# 5      6  Maria   Aprovado
# 6      9  Maria   Aprovado
# 7      2  Maria  Reprovado
# 8      6  Maria   Aprovado
# 9     10  Maria   Aprovado
# 10    10   João   Aprovado
# 11     7   João   Aprovado
# 12     4   João  Reprovado
# 13     3   João  Reprovado
# 14     7   João   Aprovado
# 15     7   João   Aprovado
# 16     2   João  Reprovado
# 17     5   João  Reprovado
# 18     4   João  Reprovado
# 19     1   João  Reprovado
# 20     7   José   Aprovado
# 21     5   José  Reprovado
# 22     1   José  Reprovado
# 23     4   José  Reprovado
# 24     0   José  Reprovado
# 25     9   José   Aprovado
# 26     5   José  Reprovado
# 27     8   José   Aprovado
# 28     0   José  Reprovado
# 29    10   José   Aprovado

# %%
# Utilizando o apply sem passar o nome da colunae com axis = 0 (coluna)
# Conseguimos acessar os valores individuais de cada linha
# Como default, o axis é 0, <axis = 0>
df_notas.apply(lambda coluna: coluna.unique(), axis = 0)
# Out:
# nota          [6, 3, 10, 7, 4, 9, 2, 5, 1, 0, 8]
# nome                         [Maria, João, José]
# e_aprovado                 [Aprovado, Reprovado]
# dtype: object

# %%
df_notas.apply(lambda linha: f"{linha['nota'] / 3:.2f} {linha['nome']}", axis = 1)
# Out:
# 0     2.00 Maria
# 1     1.00 Maria
# 2     3.33 Maria
# 3     2.33 Maria
# 4     1.33 Maria
# 5     2.00 Maria
# 6     3.00 Maria
# 7     0.67 Maria
# 8     2.00 Maria
# 9     3.33 Maria
# 10     3.33 João
# 11     2.33 João
# 12     1.33 João
# 13     1.00 João
# 14     2.33 João
# 15     2.33 João
# 16     0.67 João
# 17     1.67 João
# 18     1.33 João
# 19     0.33 João
# 20     2.33 José
# 21     1.67 José
# 22     0.33 José
# 23     1.33 José
# 24     0.00 José
# 25     3.00 José
# 26     1.67 José
# 27     2.67 José
# 28     0.00 José
# 29     3.33 José
# dtype: object

# %%
# O get permite que lidemos com uma coluna não existente 
df_notas.get('Classe', default='Não tem essa coluna')
# Out:
# 'Não tem essa coluna'

# %%
data = pd.DataFrame(np.random.randint(0, 10, (3,3)), columns = ['ativo1','ativo2', 'ativo3'])
data
# Out:
#    ativo1  ativo2  ativo3
# 0       9       4       1
# 1       3       6       7
# 2       2       0       3

# %%
def transforma_porcentagem(n):
    return n * 100

# quando temos que aplicar uma função para todos os elementos da tabela
# utilizamos apply
data.apply(transforma_porcentagem)
# Out:
#    ativo1  ativo2  ativo3
# 0     900     200     600
# 1     300     800     200
# 2     400     200     600

# %% [markdown]
# **Aplicando o Apply em colunas selecionadas**

# %%
colunas = ['ativo2', 'ativo3']
for col in colunas:
    data[col] = data.apply(lambda linha: transforma_porcentagem(linha[col]), 1)

data
# Out:
#    ativo1  ativo2  ativo3
# 0       9     400     100
# 1       3     600     700
# 2       2       0     300

# %%
df_notas['e_aprovado_bool'] = df_notas['nota'] > 5

df_notas
# Out:
#     nota   nome e_aprovado  e_aprovado_bool
# 0      6  Maria   Aprovado             True
# 1      3  Maria  Reprovado            False
# 2     10  Maria   Aprovado             True
# 3      7  Maria   Aprovado             True
# 4      4  Maria  Reprovado            False
# 5      6  Maria   Aprovado             True
# 6      9  Maria   Aprovado             True
# 7      2  Maria  Reprovado            False
# 8      6  Maria   Aprovado             True
# 9     10  Maria   Aprovado             True
# 10    10   João   Aprovado             True
# 11     7   João   Aprovado             True
# 12     4   João  Reprovado            False
# 13     3   João  Reprovado            False
# 14     7   João   Aprovado             True
# 15     7   João   Aprovado             True
# 16     2   João  Reprovado            False
# 17     5   João  Reprovado            False
# 18     4   João  Reprovado            False
# 19     1   João  Reprovado            False
# 20     7   José   Aprovado             True
# 21     5   José  Reprovado            False
# 22     1   José  Reprovado            False
# 23     4   José  Reprovado            False
# 24     0   José  Reprovado            False
# 25     9   José   Aprovado             True
# 26     5   José  Reprovado            False
# 27     8   José   Aprovado             True
# 28     0   José  Reprovado            False
# 29    10   José   Aprovado             True

# %%
df_notas['x'] = np.random.randint(0, 20, 30)

# %%
df_notas
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x
# 0      6  Maria   Aprovado             True  17
# 1      3  Maria  Reprovado            False   7
# 2     10  Maria   Aprovado             True   3
# 3      7  Maria   Aprovado             True   1
# 4      4  Maria  Reprovado            False   5
# 5      6  Maria   Aprovado             True   9
# 6      9  Maria   Aprovado             True   3
# 7      2  Maria  Reprovado            False  17
# 8      6  Maria   Aprovado             True  11
# 9     10  Maria   Aprovado             True   1
# 10    10   João   Aprovado             True   9
# 11     7   João   Aprovado             True   3
# 12     4   João  Reprovado            False  13
# 13     3   João  Reprovado            False  15
# 14     7   João   Aprovado             True  14
# 15     7   João   Aprovado             True   7
# 16     2   João  Reprovado            False  13
# 17     5   João  Reprovado            False   7
# 18     4   João  Reprovado            False  15
# 19     1   João  Reprovado            False  12
# 20     7   José   Aprovado             True  17
# 21     5   José  Reprovado            False  14
# 22     1   José  Reprovado            False  12
# 23     4   José  Reprovado            False   8
# 24     0   José  Reprovado            False  14
# 25     9   José   Aprovado             True  12
# 26     5   José  Reprovado            False   0
# 27     8   José   Aprovado             True   6
# 28     0   José  Reprovado            False   8
# 29    10   José   Aprovado             True   0

# %%
# Quando passamos um vetor/lista/array/serie precisamos do mesmo número de linhas
# do que no dataframe original
df_notas['y'] = np.random.randint(0, 20, 25)

# %%
lista_numero_com_nan = (list(np.random.randint(0, 20, 10)) 
+ [np.nan, np.nan]  
+ list(np.random.randint(0, 20, 10))
+ [np.nan, np.nan, np.nan]
+ list(np.random.randint(0, 20, 5)))

# %%
df_notas['y'] = lista_numero_com_nan

# %%
df_notas
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x     y
# 0      6  Maria   Aprovado             True  17   9.0
# 1      3  Maria  Reprovado            False   7  12.0
# 2     10  Maria   Aprovado             True   3   5.0
# 3      7  Maria   Aprovado             True   1  11.0
# 4      4  Maria  Reprovado            False   5  11.0
# 5      6  Maria   Aprovado             True   9  19.0
# 6      9  Maria   Aprovado             True   3  10.0
# 7      2  Maria  Reprovado            False  17   6.0
# 8      6  Maria   Aprovado             True  11   0.0
# 9     10  Maria   Aprovado             True   1   0.0
# 10    10   João   Aprovado             True   9   NaN
# 11     7   João   Aprovado             True   3   NaN
# 12     4   João  Reprovado            False  13  19.0
# 13     3   João  Reprovado            False  15  12.0
# 14     7   João   Aprovado             True  14   8.0
# 15     7   João   Aprovado             True   7   2.0
# 16     2   João  Reprovado            False  13   6.0
# 17     5   João  Reprovado            False   7   5.0
# 18     4   João  Reprovado            False  15   7.0
# 19     1   João  Reprovado            False  12   8.0
# 20     7   José   Aprovado             True  17   4.0
# 21     5   José  Reprovado            False  14   0.0
# 22     1   José  Reprovado            False  12   NaN
# 23     4   José  Reprovado            False   8   NaN
# 24     0   José  Reprovado            False  14   NaN
# 25     9   José   Aprovado             True  12  18.0
# 26     5   José  Reprovado            False   0   9.0
# 27     8   José   Aprovado             True   6  11.0
# 28     0   José  Reprovado            False   8  14.0
# 29    10   José   Aprovado             True   0   8.0

# %%
# Quando utilizamos o 'DataFrame.max' ignoramos os 'NaNs
df_notas['y'].max()
# Out:
# 19.0

# %%
# Obtendo a soma
# Ignorando os NaNs
df_notas['y'].sum()
# Out:
# 214.0

# %%
# Obtendo a média
df_notas['y'].sum() / df_notas.shape[0]
# Out:
# 7.133333333333334

# %%
# O 'mean' desconsidera os NaNs (Not a Number) eliminando da população
df_notas['y'].mean()
# Out:
# 8.56

# %%
df_notas['y'].sum() /25
# Out:
# 8.56

# %% [markdown]
# **Tratando valores faltantes (`NaN`)**

# %%
df_notas_bkp = df_notas.copy() #Criando uma cópia segura uehaue

# %%
# Contando o número de nulos
df_notas.isnull()
# Out:
#      nota   nome  e_aprovado  e_aprovado_bool      x      y
# 0   False  False       False            False  False  False
# 1   False  False       False            False  False  False
# 2   False  False       False            False  False  False
# 3   False  False       False            False  False  False
# 4   False  False       False            False  False  False
# 5   False  False       False            False  False  False
# 6   False  False       False            False  False  False
# 7   False  False       False            False  False  False
# 8   False  False       False            False  False  False
# 9   False  False       False            False  False  False
# 10  False  False       False            False  False   True
# 11  False  False       False            False  False   True
# 12  False  False       False            False  False  False
# 13  False  False       False            False  False  False
# 14  False  False       False            False  False  False
# 15  False  False       False            False  False  False
# 16  False  False       False            False  False  False
# 17  False  False       False            False  False  False
# 18  False  False       False            False  False  False
# 19  False  False       False            False  False  False
# 20  False  False       False            False  False  False
# 21  False  False       False            False  False  False
# 22  False  False       False            False  False   True
# 23  False  False       False            False  False   True
# 24  False  False       False            False  False   True
# 25  False  False       False            False  False  False
# 26  False  False       False            False  False  False
# 27  False  False       False            False  False  False
# 28  False  False       False            False  False  False
# 29  False  False       False            False  False  False

# %%
# Somando por coluna
df_notas.isnull().sum()
# Out:
# nota               0
# nome               0
# e_aprovado         0
# e_aprovado_bool    0
# x                  0
# y                  5
# dtype: int64

# %%
# Preenchendo os valores faltantes com '0'
df_notas = df_notas_bkp.copy()
df_notas['y'] = df_notas['y'].fillna(-10)
df_notas
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x     y
# 0      6  Maria   Aprovado             True  17   9.0
# 1      3  Maria  Reprovado            False   7  12.0
# 2     10  Maria   Aprovado             True   3   5.0
# 3      7  Maria   Aprovado             True   1  11.0
# 4      4  Maria  Reprovado            False   5  11.0
# 5      6  Maria   Aprovado             True   9  19.0
# 6      9  Maria   Aprovado             True   3  10.0
# 7      2  Maria  Reprovado            False  17   6.0
# 8      6  Maria   Aprovado             True  11   0.0
# 9     10  Maria   Aprovado             True   1   0.0
# 10    10   João   Aprovado             True   9 -10.0
# 11     7   João   Aprovado             True   3 -10.0
# 12     4   João  Reprovado            False  13  19.0
# 13     3   João  Reprovado            False  15  12.0
# 14     7   João   Aprovado             True  14   8.0
# 15     7   João   Aprovado             True   7   2.0
# 16     2   João  Reprovado            False  13   6.0
# 17     5   João  Reprovado            False   7   5.0
# 18     4   João  Reprovado            False  15   7.0
# 19     1   João  Reprovado            False  12   8.0
# 20     7   José   Aprovado             True  17   4.0
# 21     5   José  Reprovado            False  14   0.0
# 22     1   José  Reprovado            False  12 -10.0
# 23     4   José  Reprovado            False   8 -10.0
# 24     0   José  Reprovado            False  14 -10.0
# 25     9   José   Aprovado             True  12  18.0
# 26     5   José  Reprovado            False   0   9.0
# 27     8   José   Aprovado             True   6  11.0
# 28     0   José  Reprovado            False   8  14.0
# 29    10   José   Aprovado             True   0   8.0

# %%
# Preenchendo os valores faltantes com a média
df_notas = df_notas_bkp.copy()
media_y = df_notas['y'].mean()
df_notas['y'] = df_notas['y'].fillna(media_y)
df_notas
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 0      6  Maria   Aprovado             True  17   9.00
# 1      3  Maria  Reprovado            False   7  12.00
# 2     10  Maria   Aprovado             True   3   5.00
# 3      7  Maria   Aprovado             True   1  11.00
# 4      4  Maria  Reprovado            False   5  11.00
# 5      6  Maria   Aprovado             True   9  19.00
# 6      9  Maria   Aprovado             True   3  10.00
# 7      2  Maria  Reprovado            False  17   6.00
# 8      6  Maria   Aprovado             True  11   0.00
# 9     10  Maria   Aprovado             True   1   0.00
# 10    10   João   Aprovado             True   9   8.56
# 11     7   João   Aprovado             True   3   8.56
# 12     4   João  Reprovado            False  13  19.00
# 13     3   João  Reprovado            False  15  12.00
# 14     7   João   Aprovado             True  14   8.00
# 15     7   João   Aprovado             True   7   2.00
# 16     2   João  Reprovado            False  13   6.00
# 17     5   João  Reprovado            False   7   5.00
# 18     4   João  Reprovado            False  15   7.00
# 19     1   João  Reprovado            False  12   8.00
# 20     7   José   Aprovado             True  17   4.00
# 21     5   José  Reprovado            False  14   0.00
# 22     1   José  Reprovado            False  12   8.56
# 23     4   José  Reprovado            False   8   8.56
# 24     0   José  Reprovado            False  14   8.56
# 25     9   José   Aprovado             True  12  18.00
# 26     5   José  Reprovado            False   0   9.00
# 27     8   José   Aprovado             True   6  11.00
# 28     0   José  Reprovado            False   8  14.00
# 29    10   José   Aprovado             True   0   8.00

# %% [markdown]
# **Somando colunas**

# %%
df = df_notas[['x', 'y']].copy()

# %%
df
# Out:
#      x      y
# 0   17   9.00
# 1    7  12.00
# 2    3   5.00
# 3    1  11.00
# 4    5  11.00
# 5    9  19.00
# 6    3  10.00
# 7   17   6.00
# 8   11   0.00
# 9    1   0.00
# 10   9   8.56
# 11   3   8.56
# 12  13  19.00
# 13  15  12.00
# 14  14   8.00
# 15   7   2.00
# 16  13   6.00
# 17   7   5.00
# 18  15   7.00
# 19  12   8.00
# 20  17   4.00
# 21  14   0.00
# 22  12   8.56
# 23   8   8.56
# 24  14   8.56
# 25  12  18.00
# 26   0   9.00
# 27   6  11.00
# 28   8  14.00
# 29   0   8.00

# %%
# Criando uma nova coluna utilizando o loc
df.loc[:, 'soma_x_y'] = df['x'] + df['y']

# %%
df
# Out:
#      x      y  soma_x_y
# 0   17   9.00     26.00
# 1    7  12.00     19.00
# 2    3   5.00      8.00
# 3    1  11.00     12.00
# 4    5  11.00     16.00
# 5    9  19.00     28.00
# 6    3  10.00     13.00
# 7   17   6.00     23.00
# 8   11   0.00     11.00
# 9    1   0.00      1.00
# 10   9   8.56     17.56
# 11   3   8.56     11.56
# 12  13  19.00     32.00
# 13  15  12.00     27.00
# 14  14   8.00     22.00
# 15   7   2.00      9.00
# 16  13   6.00     19.00
# 17   7   5.00     12.00
# 18  15   7.00     22.00
# 19  12   8.00     20.00
# 20  17   4.00     21.00
# 21  14   0.00     14.00
# 22  12   8.56     20.56
# 23   8   8.56     16.56
# 24  14   8.56     22.56
# 25  12  18.00     30.00
# 26   0   9.00      9.00
# 27   6  11.00     17.00
# 28   8  14.00     22.00
# 29   0   8.00      8.00

# %%
# "recortando" e somando por linha
df[['x', 'y']].sum(axis=1)
# Out:
# 0     26.00
# 1     19.00
# 2      8.00
# 3     12.00
# 4     16.00
# 5     28.00
# 6     13.00
# 7     23.00
# 8     11.00
# 9      1.00
# 10    17.56
# 11    11.56
# 12    32.00
# 13    27.00
# 14    22.00
# 15     9.00
# 16    19.00
# 17    12.00
# 18    22.00
# 19    20.00
# 20    21.00
# 21    14.00
# 22    20.56
# 23    16.56
# 24    22.56
# 25    30.00
# 26     9.00
# 27    17.00
# 28    22.00
# 29     8.00
# dtype: float64

# %% [markdown]
# Excluindo uma coluna

# %%
df_notas.head()
# Out:
#    nota   nome e_aprovado  e_aprovado_bool   x     y
# 0     6  Maria   Aprovado             True  17   9.0
# 1     3  Maria  Reprovado            False   7  12.0
# 2    10  Maria   Aprovado             True   3   5.0
# 3     7  Maria   Aprovado             True   1  11.0
# 4     4  Maria  Reprovado            False   5  11.0

# %%
df_notas2 = df_notas[['nota', 'e_aprovado', 'x']]

# %%
df_notas2.head()
# Out:
#    nota e_aprovado   x
# 0     6   Aprovado  17
# 1     3  Reprovado   7
# 2    10   Aprovado   3
# 3     7   Aprovado   1
# 4     4  Reprovado   5

# %%
# Excluindo colunas com o 'Drop'
df_notas3 = df_notas.drop(columns = ['nome', 'e_aprovado_bool', 'y'])

# %%
df_notas3.head()
# Out:
#    nota e_aprovado   x
# 0     6   Aprovado  17
# 1     3  Reprovado   7
# 2    10   Aprovado   3
# 3     7   Aprovado   1
# 4     4  Reprovado   5

# %%
df_nota_bkp = df_notas.copy()

# %%
def exclui_colunas(df, colunas):
    df = df.copy()
    df = df.drop(columns = colunas)
    return df

# %%
exclui_colunas(df_notas, colunas = ['nome', 'e_aprovado_bool', 'y'])
# Out:
#     nota e_aprovado   x
# 0      6   Aprovado  17
# 1      3  Reprovado   7
# 2     10   Aprovado   3
# 3      7   Aprovado   1
# 4      4  Reprovado   5
# 5      6   Aprovado   9
# 6      9   Aprovado   3
# 7      2  Reprovado  17
# 8      6   Aprovado  11
# 9     10   Aprovado   1
# 10    10   Aprovado   9
# 11     7   Aprovado   3
# 12     4  Reprovado  13
# 13     3  Reprovado  15
# 14     7   Aprovado  14
# 15     7   Aprovado   7
# 16     2  Reprovado  13
# 17     5  Reprovado   7
# 18     4  Reprovado  15
# 19     1  Reprovado  12
# 20     7   Aprovado  17
# 21     5  Reprovado  14
# 22     1  Reprovado  12
# 23     4  Reprovado   8
# 24     0  Reprovado  14
# 25     9   Aprovado  12
# 26     5  Reprovado   0
# 27     8   Aprovado   6
# 28     0  Reprovado   8
# 29    10   Aprovado   0

# %% [markdown]
# Como o dataframe é um conjunto de séries, também podemos fazer filtros!

# %%
df_notas.head()
# Out:
#    nota   nome e_aprovado  e_aprovado_bool   x     y
# 0     6  Maria   Aprovado             True  17   9.0
# 1     3  Maria  Reprovado            False   7  12.0
# 2    10  Maria   Aprovado             True   3   5.0
# 3     7  Maria   Aprovado             True   1  11.0
# 4     4  Maria  Reprovado            False   5  11.0

# %%
df_notas[df_notas.nota > 5]
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 0      6  Maria   Aprovado             True  17   9.00
# 2     10  Maria   Aprovado             True   3   5.00
# 3      7  Maria   Aprovado             True   1  11.00
# 5      6  Maria   Aprovado             True   9  19.00
# 6      9  Maria   Aprovado             True   3  10.00
# 8      6  Maria   Aprovado             True  11   0.00
# 9     10  Maria   Aprovado             True   1   0.00
# 10    10   João   Aprovado             True   9   8.56
# 11     7   João   Aprovado             True   3   8.56
# 14     7   João   Aprovado             True  14   8.00
# 15     7   João   Aprovado             True   7   2.00
# 20     7   José   Aprovado             True  17   4.00
# 25     9   José   Aprovado             True  12  18.00
# 27     8   José   Aprovado             True   6  11.00
# 29    10   José   Aprovado             True   0   8.00

# %%
df_notas[(df_notas.nota > 5) & (df_notas.nota < 8)]
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 0      6  Maria   Aprovado             True  17   9.00
# 3      7  Maria   Aprovado             True   1  11.00
# 5      6  Maria   Aprovado             True   9  19.00
# 8      6  Maria   Aprovado             True  11   0.00
# 11     7   João   Aprovado             True   3   8.56
# 14     7   João   Aprovado             True  14   8.00
# 15     7   João   Aprovado             True   7   2.00
# 20     7   José   Aprovado             True  17   4.00

# %%
# retorna valores dentro de uma lista
# O 'isin' é similar a sintaxe 'pera' in ['banana','pera', 'maça']
df_notas[df_notas.nota.isin([3, 5, 7])]
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 1      3  Maria  Reprovado            False   7  12.00
# 3      7  Maria   Aprovado             True   1  11.00
# 11     7   João   Aprovado             True   3   8.56
# 13     3   João  Reprovado            False  15  12.00
# 14     7   João   Aprovado             True  14   8.00
# 15     7   João   Aprovado             True   7   2.00
# 17     5   João  Reprovado            False   7   5.00
# 20     7   José   Aprovado             True  17   4.00
# 21     5   José  Reprovado            False  14   0.00
# 26     5   José  Reprovado            False   0   9.00

# %%
# Negação de notas 
df_notas[~df_notas.nota.isin([3, 5, 7])]
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 0      6  Maria   Aprovado             True  17   9.00
# 2     10  Maria   Aprovado             True   3   5.00
# 4      4  Maria  Reprovado            False   5  11.00
# 5      6  Maria   Aprovado             True   9  19.00
# 6      9  Maria   Aprovado             True   3  10.00
# 7      2  Maria  Reprovado            False  17   6.00
# 8      6  Maria   Aprovado             True  11   0.00
# 9     10  Maria   Aprovado             True   1   0.00
# 10    10   João   Aprovado             True   9   8.56
# 12     4   João  Reprovado            False  13  19.00
# 16     2   João  Reprovado            False  13   6.00
# 18     4   João  Reprovado            False  15   7.00
# 19     1   João  Reprovado            False  12   8.00
# 22     1   José  Reprovado            False  12   8.56
# 23     4   José  Reprovado            False   8   8.56
# 24     0   José  Reprovado            False  14   8.56
# 25     9   José   Aprovado             True  12  18.00
# 27     8   José   Aprovado             True   6  11.00
# 28     0   José  Reprovado            False   8  14.00
# 29    10   José   Aprovado             True   0   8.00

# %%
df_notas[df_notas.nota.between(3, 7)]
# Out:
#     nota   nome e_aprovado  e_aprovado_bool   x      y
# 0      6  Maria   Aprovado             True  17   9.00
# 1      3  Maria  Reprovado            False   7  12.00
# 3      7  Maria   Aprovado             True   1  11.00
# 4      4  Maria  Reprovado            False   5  11.00
# 5      6  Maria   Aprovado             True   9  19.00
# 8      6  Maria   Aprovado             True  11   0.00
# 11     7   João   Aprovado             True   3   8.56
# 12     4   João  Reprovado            False  13  19.00
# 13     3   João  Reprovado            False  15  12.00
# 14     7   João   Aprovado             True  14   8.00
# 15     7   João   Aprovado             True   7   2.00
# 17     5   João  Reprovado            False   7   5.00
# 18     4   João  Reprovado            False  15   7.00
# 20     7   José   Aprovado             True  17   4.00
# 21     5   José  Reprovado            False  14   0.00
# 23     4   José  Reprovado            False   8   8.56
# 26     5   José  Reprovado            False   0   9.00

# %%
# Setando o índice a partir de uma coluna
# <DataFrame>

# %%
df_notas_nome = df

# %% [markdown]
# Se você quiser fazer com que os indices de linha voltem a ser numéricos, faça:

# %%
# Resetando os indices
# <DataFrame = Data_frame.reset_index()>
df_notas_nome_resetado = df_notas_nome.reset_index()

# %% [markdown]
# Alterando o nome de colunas

# %%
df_notas = df_notas.rename(columns = {
    'e_aprovado': 'Está Aprovado?',
    'x': 'Numero x'
})

df_notas.head(3)
# Out:
#    nota   nome Está Aprovado?  e_aprovado_bool  Numero x     y
# 0     6  Maria       Aprovado             True        17   9.0
# 1     3  Maria      Reprovado            False         7  12.0
# 2    10  Maria       Aprovado             True         3   5.0

# %%
# Renomeando  as colunas 
colunas = ['nota', 'nome', 'e_aprovado', 'e_aprovado_bool', 'x', 'y']
df_notas.columns = colunas

# %%
colunas = ['nota', 'nome', 'e_aprovado', 'e_aprovado_bool', 'col_num_1', 'x', 'y']
df_notas.columns = colunas
df_notas.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Viatec\Documents\Estudos\Diversidade Tech\3. DiversidadeTech\Modulo 3 - Técnicas de Programação\3. Pandas\6. Pandas - DataFrame - Final.ipynb Célula: 98 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/6.%20Pandas%20-%20DataFrame%20-%20Final.ipynb#Y151sZmlsZQ%3D%3D?line=0'>1</a> colunas = ['nota', 'nome', 'e_aprovado', 'e_aprovado_bool', 'col_num_1', 'x', 'y']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/6.%20Pandas%20-%20DataFrame%20-%20Final.ipynb#Y151sZmlsZQ%3D%3D?line=1'>2</a> df_notas.columns = colunas
#       <a href='vscode-notebook-cell:/c%3A/Users/Viatec/Documents/Estudos/Diversidade%20Tech/3.%20DiversidadeTech/Modulo%203%20-%20T%C3%A9cnicas%20de%20Programa%C3%A7%C3%A3o/3.%20Pandas/6.%20Pandas%20-%20DataFrame%20-%20Final.ipynb#Y151sZmlsZQ%3D%3D?line=2'>3</a> df_notas.head(3)
#
# File c:\Users\Viatec\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\Users\Viatec\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\Viatec\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File c:\Users\Viatec\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: int, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File c:\Users\Viatec\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 7 elements

# %% [markdown]
# Ordenando os valores

# %%
df_notas[['nome', 'nota', 'y', 'x']].sort_values('nota').head()
# Out:
#     nome  nota      y   x
# 24  José     0   8.56  14
# 28  José     0  14.00   8
# 22  José     1   8.56  12
# 19  João     1   8.00  12
# 16  João     2   6.00  13

# %%
df_notas[['nome', 'nota', 'y', 'x']].sort_values(['nota', 'x', 'y'])
# Out:
#      nome  nota      y   x
# 28   José     0  14.00   8
# 24   José     0   8.56  14
# 19   João     1   8.00  12
# 22   José     1   8.56  12
# 16   João     2   6.00  13
# 7   Maria     2   6.00  17
# 1   Maria     3  12.00   7
# 13   João     3  12.00  15
# 4   Maria     4  11.00   5
# 23   José     4   8.56   8
# 12   João     4  19.00  13
# 18   João     4   7.00  15
# 26   José     5   9.00   0
# 17   João     5   5.00   7
# 21   José     5   0.00  14
# 5   Maria     6  19.00   9
# 8   Maria     6   0.00  11
# 0   Maria     6   9.00  17
# 3   Maria     7  11.00   1
# 11   João     7   8.56   3
# 15   João     7   2.00   7
# 14   João     7   8.00  14
# 20   José     7   4.00  17
# 27   José     8  11.00   6
# 6   Maria     9  10.00   3
# 25   José     9  18.00  12
# 29   José    10   8.00   0
# 9   Maria    10   0.00   1
# 2   Maria    10   5.00   3
# 10   João    10   8.56   9

# %% [markdown]
# #### Concat
#
# Muitas vezes, queremos **juntar** dataframes relacionados em um único dataframe.
#
# Para isso, utilizamos o método **pd.concat()**

# %%
df1 = pd.DataFrame(
                    {
                        'A': [1,2,3],
                        'B': [4,5,6],
                        'C': [7,8,9]
                    })
df2 = pd.DataFrame(
                    {
                        'B': [1,2,3],
                        'C': [4,5,6],
                        'D': [7,8,9]
                    })
display(df1)
display(df2)
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    B  C  D
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df3 = pd.concat([df1, df2], axis = 0)
df3
# Out:
#      A  B  C    D
# 0  1.0  4  7  NaN
# 1  2.0  5  8  NaN
# 2  3.0  6  9  NaN
# 0  NaN  1  4  7.0
# 1  NaN  2  5  8.0
# 2  NaN  3  6  9.0

# %%
df3.loc[0]
# Out:
#      A  B  C    D
# 0  1.0  4  7  NaN
# 0  NaN  1  4  7.0

# %%
df3 = df3.reset_index(drop=True)
df3
# Out:
#      A  B  C    D
# 0  1.0  4  7  NaN
# 1  2.0  5  8  NaN
# 2  3.0  6  9  NaN
# 3  NaN  1  4  7.0
# 4  NaN  2  5  8.0
# 5  NaN  3  6  9.0

# %%
df3.loc[0]
# Out:
# A    1.0
# B    4.0
# C    7.0
# D    NaN
# Name: 0, dtype: float64

# %%
df4 = pd.concat([df1, df2], axis = 1)
df4
# Out:
#    A  B  C  B  C  D
# 0  1  4  7  1  4  7
# 1  2  5  8  2  5  8
# 2  3  6  9  3  6  9

# %%
df4['A']
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
df4['B']
# Out:
#    B  B
# 0  4  1
# 1  5  2
# 2  6  3

# %%
# Usando list comprehension para renomear as colunas de forma a saber de onde vieram
df1.columns = [f"{col}_df1" for col in df1.columns]
df1
# Out:
#    A_df1  B_df1  C_df1
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#    A_df1  B_df1  C_df1  B  C  D
# 0      1      4      7  1  4  7
# 1      2      5      8  2  5  8
# 2      3      6      9  3  6  9

# %%
df5 = pd.DataFrame(
                    {
                        'A': [1,2,3],
                        'B': [4,5,6],
                        'C': [7,8,9]
                    })
df6 = pd.DataFrame(
                    {
                        'B': [1,2,3,6],
                        'C': [4,5,6,9],
                        'D': [7,8,9,10]
                    })

# %%
pd.concat([df5, df6], axis = 0)
# Out:
#      A  B  C     D
# 0  1.0  4  7   NaN
# 1  2.0  5  8   NaN
# 2  3.0  6  9   NaN
# 0  NaN  1  4   7.0
# 1  NaN  2  5   8.0
# 2  NaN  3  6   9.0
# 3  NaN  6  9  10.0

# %%
pd.concat([df5, df6], axis = 1)
# Out:
#      A    B    C  B  C   D
# 0  1.0  4.0  7.0  1  4   7
# 1  2.0  5.0  8.0  2  5   8
# 2  3.0  6.0  9.0  3  6   9
# 3  NaN  NaN  NaN  6  9  10

# %% [markdown]
# ### Merge (join)
#
# Outra tarefa muito comum quando estamos trabalhando com bases de dados é o **cruzamento**
#
# Para fazer isso, utilizamos o método **.merge()**, cujos modos de cruzamento são:
#
# <img src="https://community.qlik.com/legacyfs/online/87693_all-joins.png" width=450>

# %%
df3 = pd.DataFrame({
    'Paises': ['Br', 'Pt', 'It'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})
df4 = pd.DataFrame({
    'Paises': ['Br', 'Pt', 'Py'],
    'valor3': [1, 2, 3],
    'valor4': [3, 4, 5]
})
display(df3)
display(df4)
# Out:
#   Paises  valor1  valor2
# 0     Br       1       3
# 1     Pt       2       4
# 2     It       3       5
#   Paises  valor3  valor4
# 0     Br       1       3
# 1     Pt       2       4
# 2     Py       3       5

# %%
# Cruzando dados da coluna 'Paises' com modo 'inner' 
# Seleção dos elementos em comum 
df3.merge(df4, how = 'inner', on = 'Paises')
# Out:
#   Paises  valor1  valor2  valor3  valor4
# 0     Br       1       3       1       3
# 1     Pt       2       4       2       4

# %%
# Left join
# A tabela da esquerda é a df3
df3.merge(df4, how = 'left', on = 'Paises')
# Out:
#   Paises  valor1  valor2  valor3  valor4
# 0     Br       1       3     1.0     3.0
# 1     Pt       2       4     2.0     4.0
# 2     It       3       5     NaN     NaN

# %%
# Right Join 
df3.merge(df4, how = 'right', on = 'Paises')
# Out:
#   Paises  valor1  valor2  valor3  valor4
# 0     Br     1.0     3.0       1       3
# 1     Pt     2.0     4.0       2       4
# 2     Py     NaN     NaN       3       5

# %%
df3 = pd.DataFrame({
    'Country': ['Br','Pt', 'It'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df4 = pd.DataFrame({
    'Paises': ['Br', 'Pt', 'Py'],
    'valor3': [1, 2, 3],
    'valor4': [3, 4, 5]
})

# %%
# Colunas que representam o mesmo tipo de valor (países/country)
# Precisamos passar o nome como 'left_on', 'right_on'
df3.merge(df4, how = 'left', left_on=['Country'], right_on=['Paises'])
# Out:
#   Country  valor1  valor2 Paises  valor3  valor4
# 0      Br       1       3     Br     1.0     3.0
# 1      Pt       2       4     Pt     2.0     4.0
# 2      It       3       5    NaN     NaN     NaN

# %%
df4 = df4.rename(columns = {'Paises': 'Country'})

# %%
display(df3)
display(df4)
# Out:
#   Country  valor1  valor2
# 0      Br       1       3
# 1      Pt       2       4
# 2      It       3       5
#   Country  valor3  valor4
# 0      Br       1       3
# 1      Pt       2       4
# 2      Py       3       5

# %%
df3.merge(df4, how='left', on = ['Country'])
# Out:
#   Country  valor1  valor2  valor3  valor4
# 0      Br       1       3     1.0     3.0
# 1      Pt       2       4     2.0     4.0
# 2      It       3       5     NaN     NaN

# %%
df3 = pd.DataFrame({
    'nome': ['João','Maria', 'Edu'],
    'sobrenome': ['Silva','Alencar', 'Deus'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df4 = pd.DataFrame({
    'nome': ['João','Maria', 'Dadinho'],
    'sobrenome': ['Silva','Alencar', 'Deus'],
    'valor3': [1, 2, 3],
    'valor4': [3, 4, 5]
})

# %%
display(df3)
display(df4)
# Out:
#     nome sobrenome  valor1  valor2
# 0   João     Silva       1       3
# 1  Maria   Alencar       2       4
# 2    Edu      Deus       3       5
#       nome sobrenome  valor3  valor4
# 0     João     Silva       1       3
# 1    Maria   Alencar       2       4
# 2  Dadinho      Deus       3       5

# %%
# Caso queira passar uma coleção de valores, passe uma lista
df3.merge(df4, on = ['nome', 'sobrenome'], how = 'inner')
# Out:
#     nome sobrenome  valor1  valor2  valor3  valor4
# 0   João     Silva       1       3       1       3
# 1  Maria   Alencar       2       4       2       4

# %%
df3.merge(df4, left_on = ['nome', 'sobrenome'], right_on = ['nome', 'sobrenome'], how = 'inner')
# Out:
#     nome sobrenome  valor1  valor2  valor3  valor4
# 0   João     Silva       1       3       1       3
# 1  Maria   Alencar       2       4       2       4

# %%
# Utilizando o join
# Juntamos os valores pelos índices
# Colocando um suffixo nos valores repetidos 
df3.join(df4, lsuffix='_df3', rsuffix='_df4')
# Out:
#   nome_df3 sobrenome_df3  valor1  valor2 nome_df4 sobrenome_df4  valor3  \
# 0     João         Silva       1       3     João         Silva       1
# 1    Maria       Alencar       2       4    Maria       Alencar       2
# 2      Edu          Deus       3       5  Dadinho          Deus       3
#
#    valor4
# 0       3
# 1       4
# 2       5

# %%
# Definindo o nome como indice
df3_nome = df3.set_index('nome')
df4_nome = df4.set_index('nome')

# %%
display(df3_nome)
display(df4_nome)
# Out:
#       sobrenome  valor1  valor2
# nome
# João      Silva       1       3
# Maria   Alencar       2       4
# Edu        Deus       3       5
#         sobrenome  valor3  valor4
# nome
# João        Silva       1       3
# Maria     Alencar       2       4
# Dadinho      Deus       3       5

# %%
df3_nome.join(df4_nome, lsuffix='_df3', rsuffix='_df4')
# Out:
#       sobrenome_df3  valor1  valor2 sobrenome_df4  valor3  valor4
# nome
# João          Silva       1       3         Silva     1.0     3.0
# Maria       Alencar       2       4       Alencar     2.0     4.0
# Edu            Deus       3       5           NaN     NaN     NaN

# %%
#

# %%
df3 = pd.DataFrame({
    'nome': ['João','Maria', 'Edu'],
    'sobrenome': ['Silva','Alencar', 'Deus'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df4 = pd.DataFrame({
    'nome': ['João','João', 'Dadinho'],
    'sobrenome': ['Silva','Alencar', 'Deus'],
    'valor3': [1, 2, 3],
    'valor4': [3, 4, 5]
})

# %%
display(df3)
display(df4)
# Out:
#     nome sobrenome  valor1  valor2
# 0   João     Silva       1       3
# 1  Maria   Alencar       2       4
# 2    Edu      Deus       3       5
#       nome sobrenome  valor3  valor4
# 0     João     Silva       1       3
# 1     João   Alencar       2       4
# 2  Dadinho      Deus       3       5

# %%
# Efeito multiplicativo de merge
# Note o nome 'João' aparece em duas linhas
df3.merge(df4, on = 'nome', how = 'left')
# Out:
#     nome sobrenome_x  valor1  valor2 sobrenome_y  valor3  valor4
# 0   João       Silva       1       3       Silva     1.0     3.0
# 1   João       Silva       1       3     Alencar     2.0     4.0
# 2  Maria     Alencar       2       4         NaN     NaN     NaN
# 3    Edu        Deus       3       5         NaN     NaN     NaN

# %%
# Evitando o efeito multiplicativo
df3.merge(df4, on=['nome', 'sobrenome'], how = 'left')
# Out:
#     nome sobrenome  valor1  valor2  valor3  valor4
# 0   João     Silva       1       3     1.0     3.0
# 1  Maria   Alencar       2       4     NaN     NaN
# 2    Edu      Deus       3       5     NaN     NaN

# %% [markdown]
# ### Transformações de dados
#
# #### GroupBy

# %%
titanic = pd.read_csv('./datasets/titanic_completa_oficial.csv')

# %% [markdown]
# Antes de inicializar qualquer análise há alguns passos importantes
# - 1-) Olhe os dados!!!
# - 2-) Verifique o tipo de dados
# - 3-) Verifique se há dados faltantes
# - 4-) Faça uma análise estatística descritiva

# %%
# Olhando os dados
titanic.head(2)
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
# Verificando o tipo de dados
# Observe:
# - O tipo era o esperado? Se há somente números, e termos um tipo `object`
#   Não seria melhor transformar a coluna em númerico?
# - Quantos dados são categóricos
# - Quantos dados númericos eu tenho?
# - O que caracteriza o meu dados? Qual o identificador (chave) -> Pense que o `id` ou `nome sobrenome` pode ser um indicativo
titanic.dtypes
# Out:
# pclass        int64
# survived      int64
# name         object
# sex          object
# age          object
# sibsp         int64
# parch         int64
# ticket       object
# fare         object
# cabin        object
# embarked     object
# boat         object
# body         object
# home.dest    object
# dtype: object

# %%
# Temos dados faltantes?
titanic.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female       2      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
# 2      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
# Observei que temos o '?'
# Vamos tratar o '?' como NaN
titanic = titanic.replace({'?':np.nan})
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic.fare.unique()
# Out:
# array(['211.3375', '151.55', '26.55', '77.9583', '0', '51.4792',
#        '49.5042', '227.525', '69.3', '78.85', '30', '25.925', '247.5208',
#        '76.2917', '75.2417', '52.5542', '221.7792', '26', '91.0792',
#        '135.6333', '35.5', '31', '164.8667', '262.375', '55', '30.5',
#        '50.4958', '39.6', '27.7208', '134.5', '26.2875', '27.4458',
#        '512.3292', '5', '47.1', '120', '61.175', '53.1', '86.5', '29.7',
#        '136.7792', '52', '25.5875', '83.1583', '25.7', '71', '71.2833',
#        '57', '81.8583', '106.425', '56.9292', '78.2667', '31.6792',
#        '31.6833', '110.8833', '26.3875', '27.75', '263', '133.65', '49.5',
#        '79.2', '38.5', '211.5', '59.4', '89.1042', '34.6542', '28.5',
#        '153.4625', '63.3583', '55.4417', '76.7292', '42.4', '83.475',
#        '93.5', '42.5', '51.8625', '50', '57.9792', '90', '30.6958', '80',
#        '28.7125', '25.9292', '39.4', '45.5', '146.5208', '82.1708',
#        '57.75', '113.275', '26.2833', '108.9', '25.7417', '61.9792',
#        '66.6', '40.125', '55.9', '60', '82.2667', '32.3208', '79.65',
#        '28.5375', '33.5', '34.0208', '75.25', '77.2875', '61.3792', '35',
#        '24', '13', '11.5', '10.5', '12.525', '39', '29', '21', '13.5',
#        '26.25', '36.75', '73.5', '31.5', '23', '32.5', '13.8583', '14.5',
#        '33', '65', '16', '12.275', '27', '15', '13.7917', '12.35',
#        '10.7083', '41.5792', '12', '12.875', '15.0458', '37.0042',
#        '15.5792', '19.5', '14', '9.6875', '30.0708', '13.8625', '15.05',
#        '12.7375', '15.0333', '18.75', '12.65', '15.75', '7.55', '20.25',
#        '7.65', '7.925', '7.2292', '7.25', '8.05', '9.475', '9.35',
#        '18.7875', '7.8875', '7.05', '8.3', '22.525', '7.8542', '31.275',
#        '7.775', '7.7958', '7.8958', '17.8', '31.3875', '7.225', '14.4583',
#        '15.85', '19.2583', '14.4542', '7.8792', '4.0125', '56.4958',
#        '7.75', '15.2458', '15.5', '16.1', '7.725', '7.0458', '7.2833',
#        '7.8208', '6.75', '8.6625', '7.7333', '7.4958', '7.6292', '15.9',
#        '8.1583', '10.5167', '10.1708', '6.95', '14.4', '24.15', '17.4',
#        '9.5', '20.575', '12.475', '13.9', '6.975', '15.1', '34.375',
#        '7.7417', '20.525', '7.85', '46.9', '8.3625', '9.8458', '8.85',
#        '19.9667', '14.1083', '6.8583', '8.9625', '12.2875', '6.45',
#        '7.0542', '8.1125', '6.4958', '8.6542', '11.1333', '23.45',
#        '9.825', '7.125', '8.4333', '7.5208', '13.4167', '7.8292',
#        '7.7375', '22.025', '12.1833', '9.5875', '9.4833', '25.4667',
#        '6.4375', '15.55', '7.5792', '7.1417', '23.25', '7.7875', '8.0292',
#        '8.4583', '15.7417', '11.2417', '7.8', '6.2375', '9.225', '3.1708',
#        '8.4042', '7.3125', '9.2167', '8.6833', '21.075', '39.6875',
#        '8.7125', '13.775', '7', '22.3583', '8.1375', '29.125', '7.7208',
#        '20.2125', '7.7292', '7.575', '69.55', '9.325', '21.6792', '16.7',
#        '7.7792', '27.9', nan, '9.8375', '10.4625', '8.5167', '9.8417',
#        '9', '18', '7.875'], dtype=object)

# %% [markdown]
# Agora temos muitos dados faltantes!
# Principalmente:
# - Idade
# - Cabine
# - Se embarcou ou não
# - Barco
# - Corpo (muitos não foram achados)
# - Destino final

# %%
# Vamos transformar algumas colunas em númericas!
for col in ['age', 'fare']:
    titanic[col] = titanic[col].astype(float)

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body          object
# home.dest     object
# dtype: object

# %% [markdown]
# Observe que temos dois nomes duplicados!
# Vamos voltar para a tabela original!

# %% [markdown]
# **Dados limpos!**
#
# Podemos começar a analisar

# %% [markdown]
# **Podemos melhorar?**
#
# Na análise de dados a forma que mostramos os dados fazem muita diferença!

# %% [markdown]
# Pode ficar ainda melhor!

# %% [markdown]
# Não gostei! As vezes o 1 está em cima as vezes o 0 em cima, vamos organizar!

# %% [markdown]
# A análise de dados envolve sempre uma estória.
#
# Qual a estória que queremos contar com os nossos dados?

# %% [markdown]
# ## Pivot

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                   'two'],
                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                        'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
